# %%
print("Hello World")
# Out:
# Hello World

# %%
import csv

with open('sharkfile.csv') as fp:
    reader = csv.DictReader(fp)
    for row in reader
        
        print (row)

# %%
import csv

with open('sharkfile.csv') as fp:
    reader = csv.DictReader(fp)
    for row in reader
        print (row)
# Out:
# OrderedDict([('Datetime_UTC', '7/26/2017 23:59'), ('Transmitter', '17784'), ('Latitude', '42.29009'), ('Longitude', '-71.00569')])
# OrderedDict([('Datetime_UTC', '7/27/2017 0:29'), ('Transmitter', '17784'), ('Latitude', '42.29009'), ('Longitude', '-71.00569')])
# OrderedDict([('Datetime_UTC', '7/27/2017 0:59'), ('Transmitter', '17784'), ('Latitude', '42.29009'), ('Longitude', '-71.00569')])
# OrderedDict([('Datetime_UTC', '7/27/2017 3:59'), ('Transmitter', '17784'), ('Latitude', '42.29009'), ('Longitude', '-71.00569')])
# OrderedDict([('Datetime_UTC', '7/27/2017 4:59'), ('Transmitter', '17784'), ('Latitude', '42.29009'), ('Longitude', '-71.00569')])
# OrderedDict([('Datetime_UTC', '7/27/2017 5:29'), ('Transmitter', '17784'), ('Latitude', '42.29009'), ('Longitude', '-71.00569')])
# OrderedDict([('Datetime_UTC', '7/27/2017 8:59'), ('Transmitter', '17784'), ('Latitude', '42.29009'), ('Longitude', '-71.00569')])
# ...
